# %% [markdown]
# <a href="https://colab.research.google.com/github/SoheilBadri2000/WebScraingForDS/blob/main/ch02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from urllib.parse import quote, quote_plus, unquote

# %%
url = "http://webscrapingfordatascience.com/"
r = requests.get(url)

print("\nResponse content (r.text):")
print(r.text)
print("\nHTTP Status code (r.status_code):")
print(r.status_code)
print("\nTextual Status code (r.reason):")
print(r.reason)
print("\nHTTP Response Hearders (r.headers):")
print(r.headers)
print("\nRequest info saved as Python object (r.request):")
print(r.request)
print("\nHTTP Request headers (r.request.headers):")
print(r.request.headers)
print("\nEncoded Parameters (r.request.url)")
print(r.request.url)
# Out:
# Response content (r.text):
# <!doctype html>
# <html lang="en">
# <head>
# 	<meta charset="utf-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1.0">
# 	<meta name="description" content="Web Scraping for Data science">
# 	<title>Practical Web Scraping for Data science</title>
#
# 	<script src="p5.min.js"></script>
# 	<script src="sketch.js"></script>
# 	<link rel="stylesheet" href="https://unpkg.com/purecss@1.0.0/build/pure-min.css" integrity="sha384-" crossorigin="anonymous">
# 	<link rel="stylesheet" href="https://unpkg.com/purecss@1.0.0/build/grids-responsive-min.css">
# 	<link href="https://fonts.googleapis.com/css?family=PT+Sans|PT+Sans+Caption|PT+Serif|PT+Serif+Caption" rel="stylesheet">
# 	<style>
# 		* {
# 			-webkit-box-sizing: border-box;
# 			-moz-box-sizing: border-box;
# 			box-sizing: border-box;
# 		}
#
# 		body {
# 			line-height: 1.7em;
# 			color: #333;
# 			font-size: 15px;
# 			font-family: 'PT Sans', sans-serif;
# 		}
#
# ...

# %%
url = "http://webscrapingfordatascience.com/basichttp/"
r = requests.get(url)

print("\nResponse content (r.text):")
print(r.text)
print("\nHTTP Status code (r.status_code):")
print(r.status_code)
print("\nTextual Status code (r.reason):")
print(r.reason)
print("\nHTTP Response Hearders (r.headers):")
print(r.headers)
print("\nRequest info saved as Python object (r.request):")
print(r.request)
print("\nHTTP Request headers (r.request.headers):")
print(r.request.headers)
print("\nEncoded Parameters (r.request.url)")
print(r.request.url)
# Out:
# Response content (r.text):
# Hello from the web!
#
#
# HTTP Status code (r.status_code):
# 200
#
# Textual Status code (r.reason):
# OK
#
# HTTP Response Hearders (r.headers):
# {'Date': 'Sun, 24 Sep 2023 18:55:37 GMT', 'Server': 'Apache/2.4.52 (Ubuntu)', 'Content-Length': '21', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=UTF-8'}
#
# Request info saved as Python object (r.request):
# <PreparedRequest [GET]>
#
# HTTP Request headers (r.request.headers):
# {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
#
# Encoded Parameters (r.request.url)
# http://webscrapingfordatascience.com/basichttp/

# %%
url = "http://webscrapingfordatascience.com/paramhttp/"
r = requests.get(url)

print("\nResponse content (r.text):")
print(r.text)
print("\nHTTP Status code (r.status_code):")
print(r.status_code)
print("\nTextual Status code (r.reason):")
print(r.reason)
print("\nHTTP Response Hearders (r.headers):")
print(r.headers)
print("\nRequest info saved as Python object (r.request):")
print(r.request)
print("\nHTTP Request headers (r.request.headers):")
print(r.request.headers)
print("\nEncoded Parameters (r.request.url)")
print(r.request.url)
# Out:
# Response content (r.text):
# Please provide a "query" parameter
#
# HTTP Status code (r.status_code):
# 200
#
# Textual Status code (r.reason):
# OK
#
# HTTP Response Hearders (r.headers):
# {'Date': 'Sun, 24 Sep 2023 18:56:40 GMT', 'Server': 'Apache/2.4.52 (Ubuntu)', 'Content-Length': '34', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=UTF-8'}
#
# Request info saved as Python object (r.request):
# <PreparedRequest [GET]>
#
# HTTP Request headers (r.request.headers):
# {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
#
# Encoded Parameters (r.request.url)
# http://webscrapingfordatascience.com/paramhttp/

# %%
url = "http://webscrapingfordatascience.com/paramhttp/?query=test"
r = requests.get(url)

print("\nResponse content (r.text):")
print(r.text)
print("\nHTTP Status code (r.status_code):")
print(r.status_code)
print("\nTextual Status code (r.reason):")
print(r.reason)
print("\nHTTP Response Hearders (r.headers):")
print(r.headers)
print("\nRequest info saved as Python object (r.request):")
print(r.request)
print("\nHTTP Request headers (r.request.headers):")
print(r.request.headers)
print("\nEncoded Parameters (r.request.url)")
print(r.request.url)
# Out:
# Response content (r.text):
# I don't have any information on "test"
#
# HTTP Status code (r.status_code):
# 200
#
# Textual Status code (r.reason):
# OK
#
# HTTP Response Hearders (r.headers):
# {'Date': 'Sun, 24 Sep 2023 18:57:18 GMT', 'Server': 'Apache/2.4.52 (Ubuntu)', 'Content-Length': '38', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=UTF-8'}
#
# Request info saved as Python object (r.request):
# <PreparedRequest [GET]>
#
# HTTP Request headers (r.request.headers):
# {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
#
# Encoded Parameters (r.request.url)
# http://webscrapingfordatascience.com/paramhttp/?query=test

# %%
url = "http://webscrapingfordatascience.com/paramhttp/?query=anothertest"
r = requests.get(url)

print("\nResponse content (r.text):")
print(r.text)
print("\nHTTP Status code (r.status_code):")
print(r.status_code)
print("\nTextual Status code (r.reason):")
print(r.reason)
print("\nHTTP Response Hearders (r.headers):")
print(r.headers)
print("\nRequest info saved as Python object (r.request):")
print(r.request)
print("\nHTTP Request headers (r.request.headers):")
print(r.request.headers)
print("\nEncoded Parameters (r.request.url)")
print(r.request.url)
# Out:
# Response content (r.text):
# I don't have any information on "anothertest"
#
# HTTP Status code (r.status_code):
# 200
#
# Textual Status code (r.reason):
# OK
#
# HTTP Response Hearders (r.headers):
# {'Date': 'Sun, 24 Sep 2023 19:00:46 GMT', 'Server': 'Apache/2.4.52 (Ubuntu)', 'Content-Length': '45', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=UTF-8'}
#
# Request info saved as Python object (r.request):
# <PreparedRequest [GET]>
#
# HTTP Request headers (r.request.headers):
# {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
#
# Encoded Parameters (r.request.url)
# http://webscrapingfordatascience.com/paramhttp/?query=anothertest

# %%
url = "http://webscrapingfordatascience.com/paramhttp/?query=another%20test%3F%26"
r = requests.get(url)

print("\nResponse content (r.text):")
print(r.text)
print("\nHTTP Status code (r.status_code):")
print(r.status_code)
print("\nTextual Status code (r.reason):")
print(r.reason)
print("\nHTTP Response Hearders (r.headers):")
print(r.headers)
print("\nRequest info saved as Python object (r.request):")
print(r.request)
print("\nHTTP Request headers (r.request.headers):")
print(r.request.headers)
print("\nEncoded Parameters (r.request.url)")
print(r.request.url)
# Out:
# Response content (r.text):
# I don't have any information on "another test?&"
#
# HTTP Status code (r.status_code):
# 200
#
# Textual Status code (r.reason):
# OK
#
# HTTP Response Hearders (r.headers):
# {'Date': 'Sun, 24 Sep 2023 19:01:15 GMT', 'Server': 'Apache/2.4.52 (Ubuntu)', 'Content-Length': '48', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=UTF-8'}
#
# Request info saved as Python object (r.request):
# <PreparedRequest [GET]>
#
# HTTP Request headers (r.request.headers):
# {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
#
# Encoded Parameters (r.request.url)
# http://webscrapingfordatascience.com/paramhttp/?query=another%20test%3F%26

# %%
url = "http://webscrapingfordatascience.com/paramhttp/?query=test&other=ignored"
r = requests.get(url)

print("\nResponse content (r.text):")
print(r.text)
print("\nHTTP Status code (r.status_code):")
print(r.status_code)
print("\nTextual Status code (r.reason):")
print(r.reason)
print("\nHTTP Response Hearders (r.headers):")
print(r.headers)
print("\nRequest info saved as Python object (r.request):")
print(r.request)
print("\nHTTP Request headers (r.request.headers):")
print(r.request.headers)
print("\nEncoded Parameters (r.request.url)")
print(r.request.url)
# Out:
# Response content (r.text):
# I don't have any information on "test"
#
# HTTP Status code (r.status_code):
# 200
#
# Textual Status code (r.reason):
# OK
#
# HTTP Response Hearders (r.headers):
# {'Date': 'Sun, 24 Sep 2023 19:01:55 GMT', 'Server': 'Apache/2.4.52 (Ubuntu)', 'Content-Length': '38', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=UTF-8'}
#
# Request info saved as Python object (r.request):
# <PreparedRequest [GET]>
#
# HTTP Request headers (r.request.headers):
# {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
#
# Encoded Parameters (r.request.url)
# http://webscrapingfordatascience.com/paramhttp/?query=test&other=ignored

# %%
url = "http://webscrapingfordatascience.com/paramhttp/?query=a query with spaces"
r = requests.get(url)

print("\nResponse content (r.text):")
print(r.text)
print("\nHTTP Status code (r.status_code):")
print(r.status_code)
print("\nTextual Status code (r.reason):")
print(r.reason)
print("\nHTTP Response Hearders (r.headers):")
print(r.headers)
print("\nRequest info saved as Python object (r.request):")
print(r.request)
print("\nHTTP Request headers (r.request.headers):")
print(r.request.headers)
print("\nEncoded Parameters (r.request.url)")
print(r.request.url)
# Out:
# Response content (r.text):
# I don't have any information on "a query with spaces"
#
# HTTP Status code (r.status_code):
# 200
#
# Textual Status code (r.reason):
# OK
#
# HTTP Response Hearders (r.headers):
# {'Date': 'Sun, 24 Sep 2023 19:05:18 GMT', 'Server': 'Apache/2.4.52 (Ubuntu)', 'Content-Length': '53', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=UTF-8'}
#
# Request info saved as Python object (r.request):
# <PreparedRequest [GET]>
#
# HTTP Request headers (r.request.headers):
# {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
#
# Encoded Parameters (r.request.url)
# http://webscrapingfordatascience.com/paramhttp/?query=a%20query%20with%20spaces

# %%
url = "http://webscrapingfordatascience.com/paramhttp/?query=complex?&"
r = requests.get(url)

print("\nResponse content (r.text):")
print(r.text)
print("\nHTTP Status code (r.status_code):")
print(r.status_code)
print("\nTextual Status code (r.reason):")
print(r.reason)
print("\nHTTP Response Hearders (r.headers):")
print(r.headers)
print("\nRequest info saved as Python object (r.request):")
print(r.request)
print("\nHTTP Request headers (r.request.headers):")
print(r.request.headers)
print("\nEncoded Parameters (r.request.url)")
print(r.request.url)
# Out:
# Response content (r.text):
# I don't have any information on "complex?"
#
# HTTP Status code (r.status_code):
# 200
#
# Textual Status code (r.reason):
# OK
#
# HTTP Response Hearders (r.headers):
# {'Date': 'Sun, 24 Sep 2023 19:06:59 GMT', 'Server': 'Apache/2.4.52 (Ubuntu)', 'Content-Length': '42', 'Keep-Alive': 'timeout=5, max=100', 'Connection': 'Keep-Alive', 'Content-Type': 'text/html; charset=UTF-8'}
#
# Request info saved as Python object (r.request):
# <PreparedRequest [GET]>
#
# HTTP Request headers (r.request.headers):
# {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}
#
# Encoded Parameters (r.request.url)
# http://webscrapingfordatascience.com/paramhttp/?query=complex?&

# %%
raw_string = "a query with /, spaces and?&"
url = "http://webscrapingfordatascience.com/paramhttp/?query="
print("\n\nUsing quote:")
# nothing is safe, even '/', encode everything
r = requests.get(url + quote(raw_string, safe=""))
print(r.url)
print(r.text)
print("\nUsing  quote_plus:")
r = requests.get(url + quote_plus(raw_string))
print(r.url)
print(r.text)
# Out:
# Using quote:
# http://webscrapingfordatascience.com/paramhttp/?query=a%20query%20with%20%2F%2C%20spaces%20and%3F%26
# I don't have any information on "a query with /, spaces and?&"
#
# Using  quote_plus:
# http://webscrapingfordatascience.com/paramhttp/?query=a+query+with+%2F%2C+spaces+and%3F%26
# I don't have any information on "a query with /, spaces and?&"

# %%
# Rewriting the code
url = "http://webscrapingfordatascience.com/paramhttp/"
parameters = {
    "query": "a query with /, spaces and ?&"
}
r = requests.get(url, params=parameters)
print(r.url)
print(r.text)
# Out:
# http://webscrapingfordatascience.com/paramhttp/?query=a+query+with+%2F%2C+spaces+and+%3F%26
# I don't have any information on "a query with /, spaces and ?&"

# %%
# Silencing requests completely
class NonEncodedSession(requests.Session):
    # Override the default send method
    def send(self, *a, **kw):
        # Revert the encoding whiich was applied
        a[0].url = unquote(a[0].url)
        return requests.Session.send(self, *a, **kw)

my_requests = NonEncodedSession()
url = "http://example.com/?spaces |pipe"
r = my_requests.get(url)
print(r.url)
# Will show: http://example.com/?spaces |pipe
# Out:
# http://example.com/?spaces |pipe

# %%
def calc(a, b, op):
    url = "http://webscrapingfordatascience.com/calchttp/"
    params = {'a': a, 'b': b, 'op': op}
    r = requests.get(url, params=params)
    return r.text

print(calc(4, 6, '*'))
print(calc(4, 6, '/'))
print(calc("4", 6, '*'))
# Out:
# 24
# 0.66666666666667
# 24

# %%
url = "https://en.wikipedia.org/w/index.php" + "?title=List_of_Game_of_Thrones_episodes&oldid=802553687"
r = requests.get(url)
print(r.url)
print(r.text)
# Out:
# https://en.wikipedia.org/w/index.php?title=List_of_Game_of_Thrones_episodes&oldid=802553687
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled vector-feature-client-preferences-disabled" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8">
# <title>List of Game of Thrones episodes - Wikipedia</title>
# ...
